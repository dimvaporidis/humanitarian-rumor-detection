# %%
import pandas as pd
import numpy as np
import string
from sklearn import preprocessing
from pathlib import Path
import json
import time

# %%
rootdir = Path('simeia')
    
file_list = [f for f in rootdir.resolve().glob('**/*') if f.is_file()]

# %%
file_list
# Out:
# [PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted5.csv'),
#  PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted13.csv'),
#  PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted2.csv'),
#  PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted_extra.csv'),
#  PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted11.csv'),
#  PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted8.csv'),
#  PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted9.csv'),
#  PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted6.csv'),
#  PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted12.csv'),
#  PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted14.csv'),
#  PosixPath('/home/dimitris/zero_to_deep_learning_udemy/simeia/generic_extracted7.csv'),
# ...

# %%
for i in range(len(file_list)):
    
    a = pd.read_csv(file_list[i],sep='\t')
    
    a = a.drop('Unnamed: 0',axis=1)
    
    a.favoutire_per_second = a.favourite_count/a.tweet_age
    
    if i == 0:
        
        df = a
        
    else:
        
        df = df.append(a)
        
    df = df.reset_index(drop=True)
    
    #for i in range(len(df)):
    
#        if np.isnan(df.favoutire_per_second[i])==True:
        
#            df.favoutire_per_second[i] = 0.0

# %%
x=df.values
np.any(np.isnan(x))
# Out:
# False

# %%
df.loc[35811,'favoutire_per_second'] = 0.0

# %%
np.argwhere(np.isnan(x))
# Out:
# array([], shape=(0, 2), dtype=int64)

# %%
df.favoutire_per_second[42874]=df.favourite_count[42874]
# Out:
# /home/dimitris/anaconda3/envs/ztdl/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.favoutire_per_second.idxmax()
# Out:
# 42874

# %%
df.favoutire_per_second.max()
# Out:
# inf

# %%
df=df.drop('favoutire_per_second',axis=1)

# %%
x = df.values

min_max_scaler = preprocessing.MinMaxScaler()

x_scaled = min_max_scaler.fit_transform(x)

df = pd.DataFrame(x_scaled, columns = df.columns)
