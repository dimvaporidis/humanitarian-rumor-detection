# %%
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.utils import shuffle
from sklearn.svm import SVC
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib

# %%
def dt_model_analysis(x):
    
    pkl_file = open( x, 'rb')
    
    mydict = pickle.load(pkl_file)
    
    pkl_file.close()
    
    df = pd.DataFrame() 
    
    df['mean_fit_time']=mydict['mean_fit_time']
    
    df['mean_score_time']=mydict['mean_score_time']
    
    df['mean_test_accuracy']=mydict['mean_test_accuracy']
    
    df['mean_test_f1']=mydict['mean_test_f1']
    
    df['mean_test_precision']=mydict['mean_test_precision']
    
    df['mean_test_recall']=mydict['mean_test_recall']
    
    df['mean_train_accuracy']=mydict['mean_train_accuracy']
    
    df['mean_train_f1']=mydict['mean_train_f1']
    
    df['mean_train_precision']=mydict['mean_train_precision']
    
    df['mean_train_recall']=mydict['mean_train_recall']
    
    df['max_depth']=mydict['param_max_depth']
    
    df['max_features']=mydict['param_max_features']
    
    df['min_leaf_samples']=mydict['param_min_samples_leaf'].astype(np.float64)
    
    df['min_samples_split']=mydict['param_min_samples_split'].astype(np.float64)
    
    df['std_test_accuracy']=mydict['std_test_accuracy']
    
    df['std_test_f1']=mydict['std_test_f1']
    
    df['std_test_precision']=mydict['std_test_precision']
    
    df['std_test_recall']=mydict['std_test_recall']
        
    print(sns.lmplot(x='mean_fit_time',y='mean_test_recall',data=df,hue='max_depth',fit_reg=False,
                markers=['v','x','^','o','.','s','p','h','d','*','2']))
    
    print(sns.lmplot(x='mean_score_time',y='mean_test_recall',data=df,hue='max_depth',fit_reg=False,
                markers=['v','x','^','o','.','s','p','h','d','*','2']))
        
    print(sns.lmplot(x='min_samples_split',y='mean_test_recall',data=df[df['max_depth']==10],fit_reg=False,
                     hue='min_leaf_samples', row='max_depth',markers=['v','x','s','d']))
       
    return df,mydict

# %%
def svm_model_analysis(x):
    
    pkl_file = open( x, 'rb')
    
    mydict = pickle.load(pkl_file)
    
    pkl_file.close()
    
    df = pd.DataFrame() 
    
    df['mean_fit_time']=mydict['mean_fit_time']
    
    df['mean_score_time']=mydict['mean_score_time']
    
    df['mean_test_accuracy']=mydict['mean_test_accuracy']
    
    df['mean_test_f1']=mydict['mean_test_f1']
    
    df['mean_test_precision']=mydict['mean_test_precision']
    
    df['mean_test_recall']=mydict['mean_test_recall']
    
    df['mean_train_accuracy']=mydict['mean_train_accuracy']
    
    df['mean_train_f1']=mydict['mean_train_f1']
    
    df['mean_train_precision']=mydict['mean_train_precision']
    
    df['mean_train_recall']=mydict['mean_train_recall']
    
    df['C']=mydict['param_C']
    
    df['gamma']=mydict['param_gamma']
    
    df['kernel']=mydict['param_kernel']
    
    df['std_test_accuracy']=mydict['std_test_accuracy']
    
    df['std_test_f1']=mydict['std_test_f1']
    
    df['std_test_precision']=mydict['std_test_precision']
    
    df['std_test_recall']=mydict['std_test_recall']
        
    print(sns.lmplot(x='gamma',y='mean_test_recall',data=df[df.kernel=='rbf'],hue='C',fit_reg=False,col='kernel',
                    markers=['v','x','^','o']))
    
    print(sns.lmplot(x='mean_fit_time',y='mean_test_recall',data=df,hue='C',col='kernel',fit_reg=False,
                markers=['v','x','^','o']))    
    
    print(sns.lmplot(x='mean_score_time',y='mean_test_recall',data=df,hue='C',col='kernel',fit_reg=False,
                markers=['v','x','^','o']))
    
    return df,mydict

# %%
def mnb_model_analysis(x):
    
    pkl_file = open( x, 'rb')
    
    mydict = pickle.load(pkl_file)
    
    pkl_file.close()
    
    df = pd.DataFrame() 
    
    df['mean_fit_time']=mydict['mean_fit_time'].astype(np.float32)
    
    df['mean_score_time']=mydict['mean_score_time'].astype(np.float32)
    
    df['mean_test_accuracy']=mydict['mean_test_accuracy'].astype(np.float32)
    
    df['mean_test_f1']=mydict['mean_test_f1'].astype(np.float32)
    
    df['mean_test_precision']=mydict['mean_test_precision'].astype(np.float32)
    
    df['mean_test_recall']=mydict['mean_test_recall'].astype(np.float32)
    
    df['mean_train_accuracy']=mydict['mean_train_accuracy'].astype(np.float32)
    
    df['mean_train_f1']=mydict['mean_train_f1'].astype(np.float32)
    
    df['mean_train_precision']=mydict['mean_train_precision'].astype(np.float32)
    
    df['mean_train_recall']=mydict['mean_train_recall'].astype(np.float32)
    
    df['alpha']=mydict['param_alpha'].astype(np.float32)
    
    df['fit_prior']=mydict['param_fit_prior']
    
    df['std_test_accuracy']=mydict['std_test_accuracy'].astype(np.float32)
    
    df['std_test_f1']=mydict['std_test_f1'].astype(np.float32)
    
    df['std_test_precision']=mydict['std_test_precision'].astype(np.float32)
    
    df['std_test_recall']=mydict['std_test_recall'].astype(np.float32)
    
    print(sns.lmplot(x='alpha',y='mean_test_recall',data=df,fit_reg=False,hue='alpha'))
    
    print(sns.lmplot(x='mean_fit_time',y='mean_test_recall',data=df,fit_reg=False,col='fit_prior',hue='alpha'))
    
    print(sns.lmplot(x='mean_score_time',y='mean_test_recall',data=df,fit_reg=False,col='fit_prior',hue='alpha'))
    
    return df,mydict

# %%
df,mydict=svm_model_analysis('svm_rumour.pkl')
# Out:
# /home/dimitris/anaconda3/envs/ztdl/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_accuracy'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/dimitris/anaconda3/envs/ztdl/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_f1'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/dimitris/anaconda3/envs/ztdl/lib/python3.5/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_precision'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
# ...

# %% [markdown]
# ## Loading Dataset

# %%
# Loading the dataset
X = pd.read_csv('normalized_generic.csv',sep='\t')
X = X.drop('Unnamed: 0',axis=1)
X = shuffle(X)

a=X.loc[X['rumor'] == 0.0]
b=X.loc[X['rumor'] == 1.0]
a=a[0:len(b)]
X=pd.concat([a,b])
X = shuffle(X)
X= X.reset_index(drop=True)

# Defining the last column of the dataframe as the output column of the model
y=X['rumor']
X = X.iloc[:, :-1]

# %% [markdown]
# ## SVM Feature Investigation

# %%
svm=SVC(C=1000,gamma=0.2,kernel='linear')
svm.fit(X,y)
# Out:
# SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.2, kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
joblib.dump(svm, 'svm_trained_model.pkl', compress=9)
# Out:
# ['svm_trained_model.pkl']

# %%
svm2=joblib.load('svm_trained_model.pkl')
svm2
# Out:
# SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.2, kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
a=np.absolute(svm2.coef_[0])

# %%
sorted_columns=np.array([x for _, x in sorted(zip(a, X.columns))])
sorted_coef=np.array(sorted(a))
#selection = [0,1,2,3,48,49,50,51,52]
sorted_coef=sorted_coef[-10:]
sorted_columns=sorted_columns[-10:]

# %%
sum(np.absolute(sorted_coef))/sum(np.absolute(svm2.coef_[0]))
# Out:
# 0.8383838522258001

# %%
def f_importances(coef, names):
    imp = coef
    imp,names = zip(*sorted(zip(imp,names)))
    plt.barh(range(len(names)), imp, align='center')
    plt.yticks(range(len(names)), names)
    plt.show()

features_names = [X.columns]
f_importances(sorted_coef, sorted_columns)
